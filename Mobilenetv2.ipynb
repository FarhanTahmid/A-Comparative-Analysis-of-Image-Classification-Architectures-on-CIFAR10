# %%
import time
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score
import seaborn as sns
from torchsummary import summary


# Define transformations for the training and test datasets, including data augmentation
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# Load CIFAR-10 dataset with increased batch size and data augmentation
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=128, shuffle=True)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=128, shuffle=False)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:03<00:00, 44075251.87it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
# Define the MobileNetV2 model
class MobileNetV2(nn.Module):
    def __init__(self):
        super(MobileNetV2, self).__init__()
        self.model = torchvision.models.mobilenet_v2(pretrained=True)
        # Change the last layer to match the number of classes in CIFAR-10 (10 classes)
        self.model.classifier[1] = nn.Linear(1280, 10)

    def forward(self, x):
        return self.model(x)

# Instantiate the network, loss function, and optimizer with GPU acceleration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
weight_decay = 1e-4  # Regularization strength
net = MobileNetV2().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001, weight_decay=weight_decay)
summary(net, (3,32,32))

# Define class names for CIFAR-10 dataset
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Lists to store training and testing metrics
train_times = []
train_losses = []
train_accuracies = []
test_losses = []
test_accuracies = []
num_epochs = 50

# Training and testing loops
for epoch in range(num_epochs):
    # Training
    net.train()  # Set the model to training mode
    start_time = time.time()  # Record the start time of the epoch
    start_event_gpu = torch.cuda.Event(enable_timing=True)
    end_event_gpu = torch.cuda.Event(enable_timing=True)

    torch.cuda.reset_max_memory_allocated()  # Reset max memory usage for each epoch

    running_loss = 0.0
    correct_predictions = 0
    total_samples = 0

    for i, data in enumerate(trainloader, 0):
        start_event_gpu.record()

        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()  # Zero the parameter gradients

        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        end_event_gpu.record()
        torch.cuda.synchronize()  # Wait for GPU to finish

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        correct_predictions += (predicted == labels).sum().item()
        total_samples += labels.size(0)

    end_time = time.time()
    epoch_time = end_time - start_time
    gpu_time = start_event_gpu.elapsed_time(end_event_gpu) / 1000.0  # Convert to seconds
    max_memory_used = torch.cuda.max_memory_allocated() / (1024 ** 2)  # Convert to megabytes
    current_memory_used = torch.cuda.memory_allocated() / (1024 ** 2)  # Convert to megabytes

    train_times.append(epoch_time)

    avg_loss = running_loss / len(trainloader)
    accuracy = correct_predictions / total_samples
    train_losses.append(avg_loss)
    train_accuracies.append(accuracy)


    # Testing
    net.eval()  # Set the model to evaluation mode
    test_loss = 0.0
    correct_predictions = 0
    total_samples = 0
    sample_images = []
    true_labels = []
    predicted_labels = []
    misclassified_images = []
    misclassified_true_labels = []
    misclassified_predicted_labels = []

    with torch.no_grad():
        all_true_labels = []
        all_predicted_labels = []
        for i, data in enumerate(testloader, 0):
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = net(inputs)
            loss = criterion(outputs, labels)

            test_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            correct_predictions += (predicted == labels).sum().item()
            total_samples += labels.size(0)
            misclassified_indices = (predicted != labels).nonzero()[:, 0]

            all_true_labels.extend(labels.cpu().numpy())
            all_predicted_labels.extend(predicted.cpu().numpy())

            # Store sample images, true labels, and predicted labels for a few examples
            for j in range(len(labels)):
                if len(sample_images) < 20:  # Store only 5 sample images
                    sample_images.append(inputs[j].cpu())
                    true_labels.append(class_names[labels[j].cpu().item()])  # Get class name instead of label number
                    predicted_labels.append(class_names[predicted[j].cpu().item()])  # Get class name instead of label number

            for idx in misclassified_indices:
                misclassified_images.append(inputs[idx].cpu())
                misclassified_true_labels.append(class_names[labels[idx].cpu().item()])
                misclassified_predicted_labels.append(class_names[predicted[idx].cpu().item()])


    avg_test_loss = test_loss / len(testloader)
    test_accuracy = correct_predictions / total_samples
    test_losses.append(avg_test_loss)
    test_accuracies.append(test_accuracy)

    # Print training statistics including average time for the current epoch
    print(f'Epoch [{epoch + 1}/{num_epochs}], '
          f'Training Loss: {avg_loss:.4f}, Training Accuracy: {accuracy * 100:.2f}%, '
          f'Test Loss: {avg_test_loss:.4f}, Test Accuracy: {test_accuracy * 100:.2f}%')

    print(f'Epoch [{epoch + 1}/{num_epochs}], '
          f'Epoch Time: {epoch_time:.2f} seconds, GPU Time: {gpu_time:.2f} seconds, '
          f'Max GPU Memory Usage: {max_memory_used:.2f} MB, Current GPU Memory Usage: {current_memory_used:.2f} MB'
          f'\n')


# Calculate the total training time
total_training_time = sum(train_times)

# Calculate the average time spent on each epoch
average_time_per_epoch = total_training_time / num_epochs

print(f'Total training time: {total_training_time:.2f} seconds')
print(f'Average time spent on each epoch: {average_time_per_epoch:.2f} seconds')

# Compute confusion matrix, accuracy, precision, and recall
conf_matrix = confusion_matrix(all_true_labels, all_predicted_labels)
accuracy = accuracy_score(all_true_labels, all_predicted_labels)
precision = precision_score(all_true_labels, all_predicted_labels, average='weighted')
recall = recall_score(all_true_labels, all_predicted_labels, average='weighted')

print(f'Accuracy: {accuracy * 100:.2f}%')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V2_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-b0353104.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-b0353104.pth
# 100%|██████████| 13.6M/13.6M [00:00<00:00, 50.7MB/s]
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 16, 16]             864
#        BatchNorm2d-2           [-1, 32, 16, 16]              64
#              ReLU6-3           [-1, 32, 16, 16]               0
#             Conv2d-4           [-1, 32, 16, 16]             288
#        BatchNorm2d-5           [-1, 32, 16, 16]              64
#              ReLU6-6           [-1, 32, 16, 16]               0
#             Conv2d-7           [-1, 16, 16, 16]             512
#        BatchNorm2d-8           [-1, 16, 16, 16]              32
#   InvertedResidual-9           [-1, 16, 16, 16]               0
#            Conv2d-10           [-1, 96, 16, 16]           1,536
#       BatchNorm2d-11           [-1, 96, 16, 16]             192
#             ReLU6-12           [-1, 96, 16, 16]               0
#            Conv2d-13             [-1, 96, 8, 8]             864
#       BatchNorm2d-14             [-1, 96, 8, 8]             192
#             ReLU6-15             [-1, 96, 8, 8]               0
#            Conv2d-16             [-1, 24, 8, 8]           2,304
#       BatchNorm2d-17             [-1, 24, 8, 8]              48
#  InvertedResidual-18             [-1, 24, 8, 8]               0
#            Conv2d-19            [-1, 144, 8, 8]           3,456
#       BatchNorm2d-20            [-1, 144, 8, 8]             288
#             ReLU6-21            [-1, 144, 8, 8]               0
#            Conv2d-22            [-1, 144, 8, 8]           1,296
#       BatchNorm2d-23            [-1, 144, 8, 8]             288
#             ReLU6-24            [-1, 144, 8, 8]               0
#            Conv2d-25             [-1, 24, 8, 8]           3,456
#       BatchNorm2d-26             [-1, 24, 8, 8]              48
#  InvertedResidual-27             [-1, 24, 8, 8]               0
#            Conv2d-28            [-1, 144, 8, 8]           3,456
#       BatchNorm2d-29            [-1, 144, 8, 8]             288
#             ReLU6-30            [-1, 144, 8, 8]               0
#            Conv2d-31            [-1, 144, 4, 4]           1,296
#       BatchNorm2d-32            [-1, 144, 4, 4]             288
#             ReLU6-33            [-1, 144, 4, 4]               0
#            Conv2d-34             [-1, 32, 4, 4]           4,608
#       BatchNorm2d-35             [-1, 32, 4, 4]              64
#  InvertedResidual-36             [-1, 32, 4, 4]               0
#            Conv2d-37            [-1, 192, 4, 4]           6,144
#       BatchNorm2d-38            [-1, 192, 4, 4]             384
#             ReLU6-39            [-1, 192, 4, 4]               0
#            Conv2d-40            [-1, 192, 4, 4]           1,728
#       BatchNorm2d-41            [-1, 192, 4, 4]             384
#             ReLU6-42            [-1, 192, 4, 4]               0
#            Conv2d-43             [-1, 32, 4, 4]           6,144
#       BatchNorm2d-44             [-1, 32, 4, 4]              64
#  InvertedResidual-45             [-1, 32, 4, 4]               0
#            Conv2d-46            [-1, 192, 4, 4]           6,144
#       BatchNorm2d-47            [-1, 192, 4, 4]             384
#             ReLU6-48            [-1, 192, 4, 4]               0
#            Conv2d-49            [-1, 192, 4, 4]           1,728
#       BatchNorm2d-50            [-1, 192, 4, 4]             384
#             ReLU6-51            [-1, 192, 4, 4]               0
#            Conv2d-52             [-1, 32, 4, 4]           6,144
#       BatchNorm2d-53             [-1, 32, 4, 4]              64
#  InvertedResidual-54             [-1, 32, 4, 4]               0
#            Conv2d-55            [-1, 192, 4, 4]           6,144
#       BatchNorm2d-56            [-1, 192, 4, 4]             384
#             ReLU6-57            [-1, 192, 4, 4]               0
#            Conv2d-58            [-1, 192, 2, 2]           1,728
#       BatchNorm2d-59            [-1, 192, 2, 2]             384
#             ReLU6-60            [-1, 192, 2, 2]               0
#            Conv2d-61             [-1, 64, 2, 2]          12,288
#       BatchNorm2d-62             [-1, 64, 2, 2]             128
#  InvertedResidual-63             [-1, 64, 2, 2]               0
#            Conv2d-64            [-1, 384, 2, 2]          24,576
#       BatchNorm2d-65            [-1, 384, 2, 2]             768
#             ReLU6-66            [-1, 384, 2, 2]               0
#            Conv2d-67            [-1, 384, 2, 2]           3,456
#       BatchNorm2d-68            [-1, 384, 2, 2]             768
#             ReLU6-69            [-1, 384, 2, 2]               0
#            Conv2d-70             [-1, 64, 2, 2]          24,576
#       BatchNorm2d-71             [-1, 64, 2, 2]             128
#  InvertedResidual-72             [-1, 64, 2, 2]               0
#            Conv2d-73            [-1, 384, 2, 2]          24,576
#       BatchNorm2d-74            [-1, 384, 2, 2]             768
#             ReLU6-75            [-1, 384, 2, 2]               0
#            Conv2d-76            [-1, 384, 2, 2]           3,456
#       BatchNorm2d-77            [-1, 384, 2, 2]             768
#             ReLU6-78            [-1, 384, 2, 2]               0
#            Conv2d-79             [-1, 64, 2, 2]          24,576
#       BatchNorm2d-80             [-1, 64, 2, 2]             128
#  InvertedResidual-81             [-1, 64, 2, 2]               0
#            Conv2d-82            [-1, 384, 2, 2]          24,576
#       BatchNorm2d-83            [-1, 384, 2, 2]             768
#             ReLU6-84            [-1, 384, 2, 2]               0
#            Conv2d-85            [-1, 384, 2, 2]           3,456
#       BatchNorm2d-86            [-1, 384, 2, 2]             768
#             ReLU6-87            [-1, 384, 2, 2]               0
#            Conv2d-88             [-1, 64, 2, 2]          24,576
#       BatchNorm2d-89             [-1, 64, 2, 2]             128
#  InvertedResidual-90             [-1, 64, 2, 2]               0
#            Conv2d-91            [-1, 384, 2, 2]          24,576
#       BatchNorm2d-92            [-1, 384, 2, 2]             768
#             ReLU6-93            [-1, 384, 2, 2]               0
#            Conv2d-94            [-1, 384, 2, 2]           3,456
#       BatchNorm2d-95            [-1, 384, 2, 2]             768
#             ReLU6-96            [-1, 384, 2, 2]               0
#            Conv2d-97             [-1, 96, 2, 2]          36,864
#       BatchNorm2d-98             [-1, 96, 2, 2]             192
#  InvertedResidual-99             [-1, 96, 2, 2]               0
#           Conv2d-100            [-1, 576, 2, 2]          55,296
#      BatchNorm2d-101            [-1, 576, 2, 2]           1,152
#            ReLU6-102            [-1, 576, 2, 2]               0
#           Conv2d-103            [-1, 576, 2, 2]           5,184
#      BatchNorm2d-104            [-1, 576, 2, 2]           1,152
#            ReLU6-105            [-1, 576, 2, 2]               0
#           Conv2d-106             [-1, 96, 2, 2]          55,296
#      BatchNorm2d-107             [-1, 96, 2, 2]             192
# InvertedResidual-108             [-1, 96, 2, 2]               0
#           Conv2d-109            [-1, 576, 2, 2]          55,296
#      BatchNorm2d-110            [-1, 576, 2, 2]           1,152
#            ReLU6-111            [-1, 576, 2, 2]               0
#           Conv2d-112            [-1, 576, 2, 2]           5,184
#      BatchNorm2d-113            [-1, 576, 2, 2]           1,152
#            ReLU6-114            [-1, 576, 2, 2]               0
#           Conv2d-115             [-1, 96, 2, 2]          55,296
#      BatchNorm2d-116             [-1, 96, 2, 2]             192
# InvertedResidual-117             [-1, 96, 2, 2]               0
#           Conv2d-118            [-1, 576, 2, 2]          55,296
#      BatchNorm2d-119            [-1, 576, 2, 2]           1,152
#            ReLU6-120            [-1, 576, 2, 2]               0
#           Conv2d-121            [-1, 576, 1, 1]           5,184
#      BatchNorm2d-122            [-1, 576, 1, 1]           1,152
#            ReLU6-123            [-1, 576, 1, 1]               0
#           Conv2d-124            [-1, 160, 1, 1]          92,160
#      BatchNorm2d-125            [-1, 160, 1, 1]             320
# InvertedResidual-126            [-1, 160, 1, 1]               0
#           Conv2d-127            [-1, 960, 1, 1]         153,600
#      BatchNorm2d-128            [-1, 960, 1, 1]           1,920
#            ReLU6-129            [-1, 960, 1, 1]               0
#           Conv2d-130            [-1, 960, 1, 1]           8,640
#      BatchNorm2d-131            [-1, 960, 1, 1]           1,920
#            ReLU6-132            [-1, 960, 1, 1]               0
#           Conv2d-133            [-1, 160, 1, 1]         153,600
#      BatchNorm2d-134            [-1, 160, 1, 1]             320
# InvertedResidual-135            [-1, 160, 1, 1]               0
#           Conv2d-136            [-1, 960, 1, 1]         153,600
#      BatchNorm2d-137            [-1, 960, 1, 1]           1,920
#            ReLU6-138            [-1, 960, 1, 1]               0
#           Conv2d-139            [-1, 960, 1, 1]           8,640
#      BatchNorm2d-140            [-1, 960, 1, 1]           1,920
#            ReLU6-141            [-1, 960, 1, 1]               0
#           Conv2d-142            [-1, 160, 1, 1]         153,600
#      BatchNorm2d-143            [-1, 160, 1, 1]             320
# InvertedResidual-144            [-1, 160, 1, 1]               0
#           Conv2d-145            [-1, 960, 1, 1]         153,600
#      BatchNorm2d-146            [-1, 960, 1, 1]           1,920
#            ReLU6-147            [-1, 960, 1, 1]               0
#           Conv2d-148            [-1, 960, 1, 1]           8,640
#      BatchNorm2d-149            [-1, 960, 1, 1]           1,920
#            ReLU6-150            [-1, 960, 1, 1]               0
#           Conv2d-151            [-1, 320, 1, 1]         307,200
#      BatchNorm2d-152            [-1, 320, 1, 1]             640
# InvertedResidual-153            [-1, 320, 1, 1]               0
#           Conv2d-154           [-1, 1280, 1, 1]         409,600
#      BatchNorm2d-155           [-1, 1280, 1, 1]           2,560
#            ReLU6-156           [-1, 1280, 1, 1]               0
#          Dropout-157                 [-1, 1280]               0
#           Linear-158                   [-1, 10]          12,810
#      MobileNetV2-159                   [-1, 10]               0
# ================================================================
# Total params: 2,236,682
# Trainable params: 2,236,682
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 3.13
# Params size (MB): 8.53
# Estimated Total Size (MB): 11.67
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/torch/cuda/memory.py:329: FutureWarning: torch.cuda.reset_max_memory_allocated now calls torch.cuda.reset_peak_memory_stats, which resets /all/ peak memory stats.
#   warnings.warn(
# Epoch [1/50], Training Loss: 1.0452, Training Accuracy: 63.79%, Test Loss: 0.7827, Test Accuracy: 73.29%
# Epoch [1/50], Epoch Time: 33.89 seconds, GPU Time: 0.06 seconds, Max GPU Memory Usage: 368.32 MB, Current GPU Memory Usage: 52.43 MB
#
# Epoch [2/50], Training Loss: 0.8106, Training Accuracy: 72.46%, Test Loss: 0.6793, Test Accuracy: 77.01%
# Epoch [2/50], Epoch Time: 34.26 seconds, GPU Time: 0.11 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 52.44 MB
#
# Epoch [3/50], Training Loss: 0.6924, Training Accuracy: 76.43%, Test Loss: 0.6237, Test Accuracy: 78.84%
# Epoch [3/50], Epoch Time: 32.75 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 53.33 MB
#
# Epoch [4/50], Training Loss: 0.6218, Training Accuracy: 78.51%, Test Loss: 0.6657, Test Accuracy: 77.37%
# Epoch [4/50], Epoch Time: 32.83 seconds, GPU Time: 0.04 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 54.00 MB
#
# Epoch [5/50], Training Loss: 0.6376, Training Accuracy: 78.50%, Test Loss: 0.5623, Test Accuracy: 80.75%
# Epoch [5/50], Epoch Time: 33.63 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 54.00 MB
#
# Epoch [6/50], Training Loss: 0.5588, Training Accuracy: 80.77%, Test Loss: 0.5356, Test Accuracy: 81.77%
# Epoch [6/50], Epoch Time: 34.61 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 53.33 MB
#
# Epoch [7/50], Training Loss: 0.5168, Training Accuracy: 82.21%, Test Loss: 0.5436, Test Accuracy: 82.03%
# Epoch [7/50], Epoch Time: 33.45 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 54.00 MB
#
# Epoch [8/50], Training Loss: 0.5057, Training Accuracy: 82.53%, Test Loss: 0.5512, Test Accuracy: 80.79%
# Epoch [8/50], Epoch Time: 33.79 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 54.00 MB
#
# Epoch [9/50], Training Loss: 0.4884, Training Accuracy: 83.16%, Test Loss: 0.5028, Test Accuracy: 83.08%
# Epoch [9/50], Epoch Time: 33.74 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 54.00 MB
#
# Epoch [10/50], Training Loss: 0.4746, Training Accuracy: 83.77%, Test Loss: 0.5294, Test Accuracy: 82.32%
# Epoch [10/50], Epoch Time: 32.77 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 53.33 MB
#
# Epoch [11/50], Training Loss: 0.4564, Training Accuracy: 84.43%, Test Loss: 0.5023, Test Accuracy: 83.03%
# Epoch [11/50], Epoch Time: 32.56 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 53.33 MB
#
# Epoch [12/50], Training Loss: 0.4377, Training Accuracy: 84.90%, Test Loss: 0.4985, Test Accuracy: 83.23%
# Epoch [12/50], Epoch Time: 33.98 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 54.00 MB
#
# Epoch [13/50], Training Loss: 0.4398, Training Accuracy: 84.85%, Test Loss: 0.4898, Test Accuracy: 83.66%
# Epoch [13/50], Epoch Time: 33.29 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 53.33 MB
#
# Epoch [14/50], Training Loss: 0.4202, Training Accuracy: 85.45%, Test Loss: 0.4985, Test Accuracy: 83.60%
# Epoch [14/50], Epoch Time: 32.33 seconds, GPU Time: 0.02 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 54.00 MB
#
# Epoch [15/50], Training Loss: 0.4163, Training Accuracy: 85.58%, Test Loss: 0.4944, Test Accuracy: 83.60%
# Epoch [15/50], Epoch Time: 33.21 seconds, GPU Time: 0.02 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 53.33 MB
#
# Epoch [16/50], Training Loss: 0.4658, Training Accuracy: 84.00%, Test Loss: 0.5691, Test Accuracy: 80.50%
# Epoch [16/50], Epoch Time: 33.19 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 54.00 MB
#
# Epoch [17/50], Training Loss: 0.4485, Training Accuracy: 84.52%, Test Loss: 0.4774, Test Accuracy: 83.58%
# Epoch [17/50], Epoch Time: 32.80 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 53.33 MB
#
# Epoch [18/50], Training Loss: 0.4026, Training Accuracy: 86.16%, Test Loss: 0.4981, Test Accuracy: 83.86%
# Epoch [18/50], Epoch Time: 32.70 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 51.82 MB
#
# Epoch [19/50], Training Loss: 0.3811, Training Accuracy: 86.66%, Test Loss: 0.4575, Test Accuracy: 84.82%
# Epoch [19/50], Epoch Time: 34.85 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 53.33 MB
#
# Epoch [20/50], Training Loss: 0.3716, Training Accuracy: 87.09%, Test Loss: 0.4876, Test Accuracy: 84.17%
# Epoch [20/50], Epoch Time: 32.52 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 54.00 MB
#
# Epoch [21/50], Training Loss: 0.3614, Training Accuracy: 87.51%, Test Loss: 0.4696, Test Accuracy: 84.36%
# Epoch [21/50], Epoch Time: 32.71 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 53.33 MB
#
# Epoch [22/50], Training Loss: 0.3556, Training Accuracy: 87.74%, Test Loss: 0.4672, Test Accuracy: 84.37%
# Epoch [22/50], Epoch Time: 33.61 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 54.00 MB
#
# Epoch [23/50], Training Loss: 0.3519, Training Accuracy: 87.91%, Test Loss: 0.4604, Test Accuracy: 84.90%
# Epoch [23/50], Epoch Time: 32.78 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 51.82 MB
#
# Epoch [24/50], Training Loss: 0.3438, Training Accuracy: 88.16%, Test Loss: 0.4569, Test Accuracy: 85.08%
# Epoch [24/50], Epoch Time: 32.55 seconds, GPU Time: 0.02 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 54.00 MB
#
# Epoch [25/50], Training Loss: 0.3428, Training Accuracy: 88.22%, Test Loss: 0.4766, Test Accuracy: 84.34%
# Epoch [25/50], Epoch Time: 33.43 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 53.33 MB
#
# Epoch [26/50], Training Loss: 0.3371, Training Accuracy: 88.29%, Test Loss: 0.4800, Test Accuracy: 84.24%
# Epoch [26/50], Epoch Time: 34.08 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 54.00 MB
#
# Epoch [27/50], Training Loss: 0.3298, Training Accuracy: 88.54%, Test Loss: 0.4786, Test Accuracy: 84.47%
# Epoch [27/50], Epoch Time: 32.32 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 54.00 MB
#
# Epoch [28/50], Training Loss: 0.3298, Training Accuracy: 88.53%, Test Loss: 0.4633, Test Accuracy: 84.77%
# Epoch [28/50], Epoch Time: 33.23 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 54.00 MB
#
# Epoch [29/50], Training Loss: 0.3246, Training Accuracy: 88.61%, Test Loss: 0.4534, Test Accuracy: 85.18%
# Epoch [29/50], Epoch Time: 32.91 seconds, GPU Time: 0.04 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 51.82 MB
#
# Epoch [30/50], Training Loss: 0.3182, Training Accuracy: 88.91%, Test Loss: 0.4519, Test Accuracy: 85.03%
# Epoch [30/50], Epoch Time: 32.22 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 53.33 MB
#
# Epoch [31/50], Training Loss: 0.3136, Training Accuracy: 89.17%, Test Loss: 0.4517, Test Accuracy: 85.32%
# Epoch [31/50], Epoch Time: 33.11 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 54.00 MB
#
# Epoch [32/50], Training Loss: 0.3108, Training Accuracy: 89.18%, Test Loss: 0.4385, Test Accuracy: 85.31%
# Epoch [32/50], Epoch Time: 32.99 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 54.00 MB
#
# Epoch [33/50], Training Loss: 0.3068, Training Accuracy: 89.42%, Test Loss: 0.4758, Test Accuracy: 84.58%
# Epoch [33/50], Epoch Time: 33.67 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 54.00 MB
#
# Epoch [34/50], Training Loss: 0.3017, Training Accuracy: 89.51%, Test Loss: 0.4706, Test Accuracy: 84.38%
# Epoch [34/50], Epoch Time: 33.16 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 54.00 MB
#
# Epoch [35/50], Training Loss: 0.2971, Training Accuracy: 89.62%, Test Loss: 0.4714, Test Accuracy: 84.64%
# Epoch [35/50], Epoch Time: 33.93 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 54.00 MB
#
# Epoch [36/50], Training Loss: 0.2901, Training Accuracy: 89.80%, Test Loss: 0.4858, Test Accuracy: 84.26%
# Epoch [36/50], Epoch Time: 32.61 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 54.00 MB
#
# Epoch [37/50], Training Loss: 0.2915, Training Accuracy: 89.96%, Test Loss: 0.4763, Test Accuracy: 84.61%
# Epoch [37/50], Epoch Time: 32.61 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 54.00 MB
#
# Epoch [38/50], Training Loss: 0.2851, Training Accuracy: 90.04%, Test Loss: 0.4745, Test Accuracy: 84.83%
# Epoch [38/50], Epoch Time: 33.69 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 54.00 MB
#
# Epoch [39/50], Training Loss: 0.2799, Training Accuracy: 90.30%, Test Loss: 0.4961, Test Accuracy: 84.64%
# Epoch [39/50], Epoch Time: 32.47 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 54.00 MB
#
# Epoch [40/50], Training Loss: 0.2789, Training Accuracy: 90.29%, Test Loss: 0.4689, Test Accuracy: 84.85%
# Epoch [40/50], Epoch Time: 34.15 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 51.62 MB
#
# Epoch [41/50], Training Loss: 0.2777, Training Accuracy: 90.25%, Test Loss: 0.4621, Test Accuracy: 84.90%
# Epoch [41/50], Epoch Time: 33.91 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 54.00 MB
#
# Epoch [42/50], Training Loss: 0.2727, Training Accuracy: 90.41%, Test Loss: 0.4901, Test Accuracy: 84.29%
# Epoch [42/50], Epoch Time: 32.69 seconds, GPU Time: 0.04 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 54.00 MB
#
# Epoch [43/50], Training Loss: 0.2652, Training Accuracy: 90.76%, Test Loss: 0.4519, Test Accuracy: 85.32%
# Epoch [43/50], Epoch Time: 32.54 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 54.00 MB
#
# Epoch [44/50], Training Loss: 0.2678, Training Accuracy: 90.64%, Test Loss: 0.4731, Test Accuracy: 84.82%
# Epoch [44/50], Epoch Time: 33.24 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 51.82 MB
#
# Epoch [45/50], Training Loss: 0.2626, Training Accuracy: 90.88%, Test Loss: 0.4624, Test Accuracy: 84.89%
# Epoch [45/50], Epoch Time: 32.88 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 54.00 MB
#
# Epoch [46/50], Training Loss: 0.2603, Training Accuracy: 90.81%, Test Loss: 0.4735, Test Accuracy: 84.88%
# Epoch [46/50], Epoch Time: 32.79 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 53.33 MB
#
# Epoch [47/50], Training Loss: 0.2575, Training Accuracy: 90.97%, Test Loss: 0.4792, Test Accuracy: 85.08%
# Epoch [47/50], Epoch Time: 34.33 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 54.00 MB
#
# Epoch [48/50], Training Loss: 0.2623, Training Accuracy: 90.71%, Test Loss: 0.4726, Test Accuracy: 85.30%
# Epoch [48/50], Epoch Time: 33.27 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 51.82 MB
#
# Epoch [49/50], Training Loss: 0.2511, Training Accuracy: 91.16%, Test Loss: 0.4698, Test Accuracy: 85.38%
# Epoch [49/50], Epoch Time: 32.33 seconds, GPU Time: 0.03 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 53.33 MB
#
# Epoch [50/50], Training Loss: 0.2554, Training Accuracy: 90.99%, Test Loss: 0.4808, Test Accuracy: 84.85%
# Epoch [50/50], Epoch Time: 32.87 seconds, GPU Time: 0.02 seconds, Max GPU Memory Usage: 369.44 MB, Current GPU Memory Usage: 54.00 MB
#
# Total training time: 1660.22 seconds
# Average time spent on each epoch: 33.20 seconds
# Accuracy: 84.85%
# Precision: 0.85
# Recall: 0.85

# %%
from prettytable import PrettyTable

# Display sample images along with true and predicted labels
plt.figure(figsize=(16, 8))
plt.suptitle('Sample Test Result', weight="bold")
for i in range(len(sample_images)):
    plt.subplot(4, 5, i + 1)
    image = sample_images[i].permute(1, 2, 0) * 0.5 + 0.5  # Unnormalize the image
    plt.imshow(image.numpy())
    plt.title(f'True: {true_labels[i]}\nPredicted: {predicted_labels[i]}')
    plt.axis('off')

plt.tight_layout()
plt.show()

# Display some correctly classified images along with true and predicted labels
plt.figure(figsize=(16, 8))
plt.suptitle('Misclassified Samples', weight="bold")
for i in range(20):
    plt.subplot(4, 5, i + 1)  # 4 rows, 5 columns for 20 images
    image = misclassified_images[i].permute(1, 2, 0) * 0.5 + 0.5  # Unnormalize the image
    plt.imshow(image.numpy())
    plt.title(f'True: {misclassified_true_labels[i]}\nPredicted: {misclassified_predicted_labels[i]}')
    plt.axis('off')

plt.tight_layout()
plt.show()

# Plotting training and testing metrics
plt.figure(figsize=(16, 6))

# Plot training time
plt.subplot(1, 4, 1)
plt.plot(train_times, marker='o', linestyle='-', color='b')
plt.xlabel('Epoch')
plt.ylabel('Time (seconds)')
plt.title('Training Time for Each Epoch')
plt.grid(True)

# Plot training and testing loss curves
plt.subplot(1, 4, 2)
plt.plot(train_losses, marker='o', linestyle='-', color='r', label='Training')
plt.plot(test_losses, marker='o', linestyle='-', color='g', label='Test')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Loss Curves')
plt.legend()
plt.grid(True)

# Plot training and testing accuracy curves
plt.subplot(1, 4, 3)
plt.plot(train_accuracies, marker='o', linestyle='-', color='r', label='Training')
plt.plot(test_accuracies, marker='o', linestyle='-', color='g', label='Test')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Test Accuracy Curves')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()


# Visualize confusion matrix
plt.figure(figsize=(8, 6))
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
from prettytable import PrettyTable

# Create a colored table for accuracy, precision, and recall
table = PrettyTable(['Metric', 'Value'])
table.title = 'Model Metrics'
table.align['Metric'] = 'l'
table.align['Value'] = 'r'
table.add_row(['\033[92mAccuracy\033[0m', f'{accuracy * 100:.2f}%'])
table.add_row(['\033[91mPrecision\033[0m', f'{precision:.2f}'])
table.add_row(['\033[94mRecall\033[0m', f'{recall:.2f}'])

# Print the colored table
print(table)
# Out:
# +--------------------+
# |   Model Metrics    |
# +-----------+--------+
# | Metric    |  Value |
# +-----------+--------+
# | Accuracy  | 84.85% |
# | Precision |   0.85 |
# | Recall    |   0.85 |
# +-----------+--------+
